# %%
l1=['Ramesh','Suresh','Sathish']
l2=[20,30,40]
for i in range(len(l1)):
    print(l1[i],l2[i])
# Out:
# Ramesh 20
# Suresh 30
# Sathish 40

# %% [markdown]
# ## ZIP

# %%
l1=['Ramesh','Suresh','Sathish']
l2=[20,30,40]
l3=['Hyd','Mumbai','Chennai']
for i,j,k in zip(l1,l2,l3):
    print(i,j,k)
# Out:
# Ramesh 20 Hyd
# Suresh 30 Mumbai
# Sathish 40 Chennai

# %% [markdown]
# ## Dictionary
# - strings represents in quotes
# - list represented in square brackets
# - tuple represented in parenthases
# - sets represent in curly braces with only one value
# - Dictionary also represents in curly braces with two values
# - Dictionary has key:value pair
# - Dictionary elements are in pair
#     - one element called as key
#     - another element called as value

# %% [raw]
# l1=['Ramesh','Suresh','Sathish']
# l2=[20,30,40]
# {key:value}
# {key1:value1,key2:value2,key3:value3}

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %%
type(dict1)
# Out:
# dict

# %%
- initialization
- inbuilt function
    - max
    - min
    - len
    - sum
    - sorted
    - slicing
    - methods

# %%
dict1={20:'Ramesh',30:'Suresh'}
dict1
# Out:
# {20: 'Ramesh', 30: 'Suresh'}

# %%
dict1={'Ramesh':'20','Suresh':'30','Satish':'40'}
dict1
# Out:
# {'Ramesh': '20', 'Suresh': '30', 'Satish': '40'}

# %%
dict1={'Ramesh':20,'Suresh':30,40:'Satish'}
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 30, 40: 'Satish'}

# %%
dict1={'Ramesh':20,'Ramesh':30}
dict1
#keys are important
#when same keys but different value
#it will take the latest value
# Out:
# {'Ramesh': 30}

# %%
d5={'Ramesh':20,'Suresh':20}
d5
# Out:
# {'Ramesh': 20, 'Suresh': 20}

# %%
d6={'Ramesh':20,'Ramesh':20}
d6
# Out:
# {'Ramesh': 20}

# %%
d7={'Fruit':'Apple','Cost':10.5,'Count':100,'ava':True}
d7
# Out:
# {'Fruit': 'Apple', 'Cost': 10.5, 'Count': 100, 'ava': True}

# %%
d8={True:'Yes'}
d8
# Out:
# {True: 'Yes'}

# %%
d9={'age':[10,20,30]}
d9
# list can be a value
# Out:
# {'age': [10, 20, 30]}

# %%
d10={[10,20,30]:'age'}
d10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 d10={[10,20,30]:'age'}
#       2 d10
#
# TypeError: unhashable type: 'list'

# %%
d11={'age':(10,20,30)}
d11
# Out:
# {'age': (10, 20, 30)}

# %%
d10={(10,20,30):'age'}
d10
# Out:
# {(10, 20, 30): 'age'}

# %% [markdown]
# - list is mutable
# - tuple is immutable
# - so list cannot be a key
# - **keys are important**

# %%
d13={(10,20,30):['A','B','C']}
d13
# Out:
# {(10, 20, 30): ['A', 'B', 'C']}

# %%
d14={['A','B','C']:(10,20,30)}
d14
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 d14={['A','B','C']:(10,20,30)}
#       2 d14
#
# TypeError: unhashable type: 'list'

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
max(dict1)
# Out:
# 'Suresh'

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
min(dict1)
# Out:
# 'Ramesh'

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
len(dict1)
# Out:
# 3

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
sorted(dict1)
# Out:
# ['Ramesh', 'Satish', 'Suresh']

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
list(reversed(dict1.keys()))
# Out:
# ['Satish', 'Suresh', 'Ramesh']

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
list(reversed(dict1))
# Out:
# ['Satish', 'Suresh', 'Ramesh']

# %%
dict1={'Ramesh':20,'Suresh':30,'Satish':40}
sum(dict1.values())
# Out:
# 90

# %%
dict1={'Ramesh':20,'Suresh':30,40:'Satish'}
list(reversed(dict1))
# Out:
# [40, 'Suresh', 'Ramesh']

# %% [markdown]
# - Max/Min/sorted can work for homogenous
# - sum is only work for number only
# - reversed can work anyone

# %% [markdown]
# ## Index

# %%
l=[10,20,30]
l[0]
# Out:
# 10

# %%
s='python'
s[0]
# Out:
# 'p'

# %%
dict1={'Ramesh':20,'Suresh':30}
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 2
#       1 dict1={'Ramesh':20,'Suresh':30}
# ----> 2 dict1[0]
#
# KeyError: 0

# %%
dict1['Ramesh']
# Out:
# 20

# %%
di1={'Ramesh':20,'Suresh':30}
di1['Ramesh']
di1['Suresh']
# Out:
# 30

# %%
d1={'Ramesh':20,'Suresh':30}
for i in d1:
    print(i,d1[i])
# Out:
# Ramesh 20
# Suresh 30

# %% [markdown]
# - whenever we iterate dictionary using for loop in operator it will give keys
# - if want to get value we will access through keys only
# - keys will work as index

# %%
d1={'Fruits':['Apple','Banana','Cherry']}
d1['Fruits'][2]
# Out:
# 'Cherry'

# %%
d1={'Fruites':{'Apple':['Sweet','Green','custred']}}
d1['Fruites']['Apple'][1]
# Out:
# 'Green'

# %%
d1={'Fruites':[{'Cost':[100,200,300]}]}
d1['Fruites'][0]['Cost'][2]
# Out:
# 300

# %%
d1={'Fruites':['Apple'],'Cost':[{'1kg':[300,500],'2kg':['None']}]}
d1['Cost'][0]['2kg'][0]
# Out:
# 'None'

# %%
d1={'Fruites':{'Mango':{'Nagpur':{'MH':{'King':{'Shivaji':{'Shambaji'}}}}}}}
d1['Fruites']['Mango']['Nagpur']['MH']['King']['Shivaji']
# Out:
# {'Shambaji'}

# %% [markdown]
# **how to convert list to dictionary**

# %%
name=['Ramesh','Suresh','Satish']
age=[20,30,40]
dict1={}
dict1['Ramesh']=20
dict1['Suresh']=30
dict1['Satish']=40
for i,j in zip(name,age):
    dict1[i]=j
dict1
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %% [markdown]
# **how to convert dictionary to list**

# %%
#string to lst
# lst to string 
# lst to dict
# dict to lst

# %%
d={'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys,values=[],[]
for key in d:
    keys.append(key)
    values.append(d[key])
keys,values
# Out:
# (['Ramesh', 'Suresh', 'Satish'], [20, 30, 40])

# %%
name=['Ramesh','Suresh','Satish']
age=[20,30,40]
{i:j for i,j in zip(name,age)}
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %% [markdown]
# **mutable immutable**
# - list are mutable
# - strings are immutable
# - tuple are immutable
# - dictionary also mutable we can modify the value of a dictionary

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d['Ramesh']=40
d
# Out:
# {'Ramesh': 40, 'Suresh': 30, 'Satish': 40}

# %% [markdown]
# - dictionary is similar to database operatios
# - keys always unique but values can be change

# %% [markdown]
# **concatenation**

# %%
d1={'Ramesh':20}
d2={'Fruit':'Apple'}
d1+d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 d1={'Ramesh':20}
#       2 d2={'Fruit':'Apple'}
# ----> 3 d1+d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %% [markdown]
# **items-values-keys**

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.items()
# Out:
# dict_items([('Ramesh', 20), ('Suresh', 30), ('Satish', 40)])

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.values()
# Out:
# dict_values([20, 30, 40])

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.keys()
# Out:
# dict_keys(['Ramesh', 'Suresh', 'Satish'])

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys=d.keys()
keys
# Out:
# dict_keys(['Ramesh', 'Suresh', 'Satish'])

# %%
type(keys)
# Out:
# dict_keys

# %% [markdown]
# - dict_keys is a type of keys represented in a list
# - it look like list but not list
# - we cannot use list methods here
# - for that we need to convert dict_keys to list

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys=d.keys()
list(keys)
# Out:
# ['Ramesh', 'Suresh', 'Satish']

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
values=d.values()
list(values)
# Out:
# [20, 30, 40]

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys,values=[],[]
for key in d:
    keys.append(key)
    values.append(d[key])
keys,values
#######################################################################
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys=[key for key in d]
values=[d[key]for key in d]
#######################################################################
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
keys=list(d.keys())
values=list(d.values())

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
#d = {'ramesh': '20', 'Suresh': '30', 'Satish': '40'}

# %%
[i.lower() for i in list(d.keys())]
[str(i) for i in list(d.values())]
{key:value for key,value in zip(keys,values)}
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}

# %% [markdown]
# ## Get Method

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.get('Ramesh')
# Out:
# 20

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.get('Sam')

# %%
d['Ram']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 d['Ram']
#
# KeyError: 'Ram'

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.get('Ramesh') #ans
d.get('r') #no error no ans
########################
d['Ramesh'] #normal way
d['r'] #error

# %% [markdown]
# **Update**

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d1={'fruits':'Apple'}
d.update(d1)
d
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40, 'fruits': 'Apple'}

# %%
d.update(Apple=200)
d
# Out:
# {'Ramesh': 20, 'Suresh': 30, 'Satish': 40, 'fruits': 'Apple', 'Apple': 200}

# %%
t=(200,'marks')
l=[t]
d.update([(200,'marks')])
d
# Out:
# {'Ramesh': 20,
#  'Suresh': 30,
#  'Satish': 40,
#  'fruits': 'Apple',
#  'Apple': 200,
#  200: 'marks'}

# %% [markdown]
# - concatenate of two dictionary
# - but we can combine

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d1={'fruits':'Apple'}
d.update(d1)
d.update(Apple=200)
d.update([(200,'marks')])

# %% [markdown]
# **pop-popitem**

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.pop('Ramesh')
d
# Out:
# {'Suresh': 30, 'Satish': 40}

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.pop('r')
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 2
#       1 d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
# ----> 2 d.pop('r')
#       3 d
#
# KeyError: 'r'

# %%
l=[100,200,333,444,555]
l.pop(0) #in list it is expecting index
l
# Out:
# [200, 333, 444, 555]

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
d.popitem()
# Out:
# ('Satish', 40)

# %%
d
# Out:
# {'Ramesh': 20, 'Suresh': 30}

# %% [markdown]
# - pop will expect a key, corresponding value will be removed
#     - pop will return the **value which is removing**
# - pop item has no arguement, last key-value pair will be removed
#     - pop item return last **key-value pair**

# %% [markdown]
# **del**

# %%
l=[100,200,300,400]
del l[0]
l
# Out:
# [200, 300, 400]

# %%
l=[100,200,300,400]
del l # l is gone here
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 l=[100,200,300,400]
#       2 del l # l is gone here
# ----> 3 l
#
# NameError: name 'l' is not defined

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
del d['Ramesh']
d
# Out:
# {'Suresh': 30, 'Satish': 40}

# %%
d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
del d
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 d = {'Ramesh': 20, 'Suresh': 30, 'Satish': 40}
#       2 del d
# ----> 3 d
#
# NameError: name 'd' is not defined

# %% [markdown]
# - count in strings also in list
# - index in strings also in list
# - find in string but not in list
# - pop in list also in dictionary
# - remove in list but in dictionary pop item
# - concatination in list === extend in list
# - access value using key in dict ===== get method
# - del for list and dictionary
# - sorted ans reversed for all
